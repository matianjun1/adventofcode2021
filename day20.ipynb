##.###...###..#...#.#...#.###.###....##.#.....#...##..#..#...##.#.#..#.######.#.....##...#.#....#.##
##.####.#.##..#...#.#.#.#.##..#..#.#.##.#..#.#...#.###.#.#.##...##..#.###....#.#..###.#.#.#######.#.
.#...###.....##......#.....##.#..#..##.##..#######.#..#...#####.#.#.....#.#..#.##..#.....##.###.##..
##..#.#.###...#.##...###.#.##......##.##.###..#....####.###.#.#..###...####.###..###.##.....#.#.####
.##.#.#..###.#.#..#....###.#.###..##.#..##.##.##..#.##.######.##.#.......#.##.##.##....#.....####...
..#.##.#..#.##.##....#.#...#.#######...###..##.######.##...#.###.#####..#.##.#.##...#..##.####......
#.#.#..#....#..##...##...#......#.#..#.##.#######......##...##..#....#..#...##.#.###..##.#..##.#..#.
..#.#....#....#.#...##...#.#.#.##.###...#..#..###...###.##..#.##..##..#.##.###.#.#.##...#####.#.###.
.#..###..#.#...##.#####..####.#.###..#####.####.##.#.....#...#..###.###.###..#..#...#..#.#..#####.##
...#.#########.##....#.#.#.####.#.###..#.#..#.#..#.#####.###.#....#.#....#.#.####.####.#..#......#..
##...#.###...#..#.#.##.#.#......#...#.#.....#.###.#.....#..#.##..######..#...##....#.#.#........###.
###.#.##.###..#....#####.#..#..##.#.###..#.#..##.###.#..##..###.#..##.###.##.#.....#.....#..#.....#.
.##.###..#..#.##..####....##..#.....#.#..########.###...#.##..#...######..#.#..#......#.###.#.####..
'''.replace(".", "0").replace("#", "1").strip().split('\n')
# algorithm = list('''
# ..#.#..#####.#.#.#.###.##.....###.##.#..###.####..#####..#....#..#..##..###..######.###...####..#..#####..##..#.#####...##.#.#..#.##..#.#......#.###.######.###.####...#.##.##..#..#..#####.....#.#....###..#.##......#.....#..#..#..##..#...##.######.####.####.#.#...#.......#..#.#.#...####.##.#......#..#...##.#.##..#...##.#.##..###.#......#.#.......#.#.#.####.###.##...#.....####.#..#..#.##.#....##..#.####....##...##..#...#......#.#.......#.......##..####..#...#.#.#...##..#.#..###..#####........#..####......#..#
# '''.replace(".", "0").replace("#", "1").strip())
# inputs = '''
# #..#.
# #....
# ##..#
# ..#..
# ..###
# '''.replace(".", "0").replace("#", "1").strip().split('\n')
inputs = [list(line) for line in inputs]
# print(len(inputs), len(inputs[0]))

# %%
from functools import lru_cache
@lru_cache(maxsize=None)
def get_light(binary):
    return algorithm[int("".join(binary), 2)]

# %%
new = inputs

# %%
for xxx in range(2):
    default = "1" if xxx % 2 != 0 else "0"
    inputs = new
    inputs.insert(0, [default] * len(inputs[0]))
    inputs.insert(0, [default] * len(inputs[0]))
    inputs.append([default] * len(inputs[0]))
    inputs.append([default] * len(inputs[0]))
    for line in inputs:
        line.insert(0, default)
        line.insert(0, default)
        line.append(default)
        line.append(default)

    new = []
    for i in range(len(inputs)-2):
        new_line = []
        for j in range(len(inputs[i])-2):
            aaa = tuple(inputs[i+k][j+l] for k in range(3) for l in range(3))
            # print(aaa)
            new_line.append(get_light(aaa))
        new.append(new_line)

# %%
total = 0
for line in new:
    for x in line:
        if x == "1":
            total += 1

print("puzzle 1:", total)
# Out:
# puzzle 1: 5349

# %%
for xxx in range(50 - 2):
    default = "1" if xxx % 2 != 0 else "0"
    inputs = new
    inputs.insert(0, [default] * len(inputs[0]))
    inputs.insert(0, [default] * len(inputs[0]))
    inputs.append([default] * len(inputs[0]))
    inputs.append([default] * len(inputs[0]))
    for line in inputs:
        line.insert(0, default)
        line.insert(0, default)
        line.append(default)
        line.append(default)

    new = []
    for i in range(len(inputs)-2):
        new_line = []
        for j in range(len(inputs[i])-2):
            aaa = tuple(inputs[i+k][j+l] for k in range(3) for l in range(3))
            # print(aaa)
            new_line.append(get_light(aaa))
        new.append(new_line)

# %%
total = 0
for line in new:
    for x in line:
        if x == "1":
            total += 1

print("puzzle 2:", total)
# Out:
# puzzle 2: 15806
